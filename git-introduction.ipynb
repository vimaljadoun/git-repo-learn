# %% [markdown]
# ### Introduction to GitHub
# A version control repository for software or code development.
# Generate code and write that to current directory and commit it to save that in github.
